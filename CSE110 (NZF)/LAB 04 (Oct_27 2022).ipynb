# %% [markdown]
# <a href="https://colab.research.google.com/github/SiliconJelly/BRACU/blob/main/CSE110%20(NZF)/LAB%2004%20(Oct_27%202022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (4th lab) from these tasks, at CSE110 — 
# we mainly test our knowledge about "STRINGS"

print("Me     : \"Strings actually are array of characters\"\nPython : \"Well yes, but no\"\n")
print(" >>>    sTrInGs aRe iMmUtAbLe", end = "    <<< ")

  # DOC link for the task sets:
  # https://docs.google.com/document/d/123-t7jBHo8yP2ZArqbZh7axj9Q_htfax

# %% [markdown]
# ![strings.png](data:image/png;base64,...)

# %%
# practice

str1 = input("Please Enter your Own String : ")
alphabets = digits = special = 0

for i in range(len(str1)):
    if((str1[i] >= 'a' and str1[i] <= 'z') or (str1[i] >= 'A' and str1[i] <= 'Z')): 
        alphabets = alphabets + 1 
    elif(str1[i] >= '0' and str1[i] <= '9'):
        digits = digits + 1
    else:
        special = special + 1
        
print("\nTotal Number of Alphabets in this String :  ", alphabets)
print("Total Number of Digits in this String :  ", digits)
print("Total Number of Special Characters in this String :  ", special)

# %%
# Task 01
# approach 01

a = input()
for i in range(len(a)-1, -1, -1):
 print(a[i], end ="")

# approach 02
# slicing utilized

# s = input()
# print(s[::-1])

# %%
# Task 02

x = input()
n = int(input())
y = ""

i = 0
while i < len(x):
  i <= n

s = input()
print(s[::-1])

for i in range

# %%
# Task 03

flag = True
x = int

s = input("Enter a string: ")
print (s[::-1])

# %%
# Task 04

# i = input()
# if i.endswith("er"):
#   print(i[:-2]+"est")
# elif i.endswith("est"):
#   print(i)
# elif len(i) < 4:
#   print(i)
# elif len(i) > 3:
#   print(i+"er")


# approach 02
# using endswith() and replace() methods
wrd = str(input())
length = len(wrd)
if length > 2: # ber, shall return best
  if wrd.endswith("er"):
    new_wrd = wrd.replace("er","est")
    print(new_wrd)
  elif wrd.endswith("est"):
    print(wrd)
  else:
    print(wrd+"er") 
else:
  print(wrd)

# %%
# Task 05

wrd = input()
lnth = len(wrd)
for ltr in range(lnth):
  for len in range(ltr+1, lnth+1):
    print(wrd[ltr: len])
  break

# %%
# Task 06

txt = input()
txt_ln = len(txt)
for char in txt:
  ascii = ord(char)
  print(char, ':', ascii)

# %%
# Task 07

name = input()

for itr in name:
  if itr == "z":
    print("a",end='')
  else:
    print(chr(ord(itr)+1),end="")

# %%
# Task 08

wrd = input()
odd = wrd[1::2]
wrd2 = ""

for itr in odd:
  if 97 <= ord(itr) <= 122:
    wrd2 += chr(ord(itr) - 32)
    
print(wrd2)

# %%
# Task 09
# approach 01

ans = ""
var = input()
for i in range(len(var)-1):
  if var[i] == var[i+1]:
    continue

  else:
    ans += var[i]
print(ans+var[-1])


# approach 02

# str1 = input()
# odd=str1[1::2]
# str2 = ""
# for char in odd:
#   if 97<= ord(char)<=122:
#     str2 += chr(ord(char)-32)
# print(str2)

# %%
# Task 10

word = input()
for indx in range(len(word)):
  if word [indx] == "," and word[indx + 1] == " ":
    str1 = word[:indx]
    str2 = word[indx+2:]
    
if len(str1)<len(str2):
    smaller = str1
    larger = str2
else:
    larger = str1
    smaller = str2

ans = ""

for i in range(len(smaller)):
  if i < len(smaller):
    ans += str1[i]
    ans += str2[i]
  else:
    ans += larger[i:]
ans += larger[i+1:]
print(ans)

# %% [markdown]
# Tracing

# %%
# Task 11

i = 10
while(i >= -20):
    if(i < 0):
        test = " != "
        test = str(i//2) + test + str(int(i/2))
    else:
        test = " == "
        test = str(i//2) + test + str(int(i/2))
    print(test)
    i -= 5
                                                                                        
# https://pythontutor.com/render.html#code=i%20%3D%2010%0Awhile%28i%20%3E%3D%20-20%29%3A%0A%20%20%20%20if%28i%20%3C%200%29%3A%0A%20%20%20%20%20%20%20%20test%20%3D%20%22%20!%3D%20%22%0A%20%20%20%20%20%20%20%20test%20%3D%20str%28i//2%29%20%2B%20test%20%2B%20str%28int%28i/2%29%29%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20test%20%3D%20%22%20%3D%3D%20%22%0A%20%20%20%20%20%20%20%20test%20%3D%20str%28i//2%29%20%2B%20test%20%2B%20str%28int%28i/2%29%29%0A%20%20%20%20print%28test%29%0A%20%20%20%20i%20-%3D%205&cumulative=false&curInstr=44&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %%
# Task 12

test = ""
i = 0
j = 0
k = 15
test = "-->"
while i < 5:
    j = k - 1
    k -= 1
    while j > 10:
        test = str(i + j) + "-->" + test
        print(test)
        j -= 1
    i += 1

# https://pythontutor.com/render.html#code=test%20%3D%20%22%22%0Ai%20%3D%200%0Aj%20%3D%200%0Ak%20%3D%2015%0Atest%20%3D%20%22--%3E%22%0Awhile%20i%20%3C%205%3A%0A%20%20%20%20j%20%3D%20k%20-%201%0A%20%20%20%20k%20-%3D%201%0A%20%20%20%20while%20j%20%3E%2010%3A%0A%20%20%20%20%20%20%20%20test%20%3D%20str%28i%20%2B%20j%29%20%2B%20%22--%3E%22%20%2B%20test%0A%20%20%20%20%20%20%20%20print%28test%29%0A%20%20%20%20%20%20%20%20j%20-%3D%201%0A%20%20%20%20i%20%2B%3D%201&cumulative=false&curInstr=29&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %%
# Task 13

test = ""
i = 5
j = 0
k = 15
while i< 10:
    k-=1
    j = k
    while j > 10:
        if (j % 2) == 0:
            test = "<--"
            test = str(test) + str(i) + str(2) + "-->" + str(int(j / 2))  
        else:
            test = "-->"
            test = "-->" + str(int(i / 2)) + str(test) + str(j)
        print(test)
        j = j-1
    i+=1

# https://pythontutor.com/render.html#code=test%20%3D%20%22%22%0Ai%20%3D%205%0Aj%20%3D%200%0Ak%20%3D%2015%0Awhile%20i%3C%2010%3A%0A%20%20%20%20k-%3D1%0A%20%20%20%20j%20%3D%20k%0A%20%20%20%20while%20j%20%3E%2010%3A%0A%20%20%20%20%20%20%20%20if%20%28j%20%25%202%29%20%3D%3D%200%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20test%20%3D%20%22%3C--%22%0A%20%20%20%20%20%20%20%20%20%20%20%20test%20%3D%20str%28test%29%20%2B%20str%28i%29%20%2B%20str%282%29%20%2B%20%22--%3E%22%20%2B%20str%28int%28j%20/%202%29%29%20%20%0A%20%20%20%20%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20test%20%3D%20%22--%3E%22%0A%20%20%20%20%20%20%20%20%20%20%20%20test%20%3D%20%22--%3E%22%20%2B%20str%28int%28i%20/%202%29%29%20%2B%20str%28test%29%20%2B%20str%28j%29%0A%20%20%20%20%20%20%20%20print%28test%29%0A%20%20%20%20%20%20%20%20j%20%3D%20j-1%0A%20%20%20%20i%2B%3D1%0A%0A&cumulative=false&curInstr=90&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %%
# Task 14

test = ""
i = 5
j = 0
k = 15
while (i< 10): 
    k-=1
    j = k
    while (j > 10 ):
        if j % 2 == 0:
            test = "<--"
            test = test + str( i) + '3' + "-->" + str(j // 3)
        else:
            test = "-->"
            test = "-->" + str((i // 3)) + test + str(j)
        print(test)
        j -=1
    i+=1

# https://pythontutor.com/render.html#code=test%20%3D%20%22%22%0Ai%20%3D%205%0Aj%20%3D%200%0Ak%20%3D%2015%0Awhile%20%28i%3C%2010%29%3A%20%0A%20%20%20%20k-%3D1%0A%20%20%20%20j%20%3D%20k%0A%20%20%20%20while%20%28j%20%3E%2010%20%29%3A%0A%20%20%20%20%20%20%20%20if%20j%20%25%202%20%3D%3D%200%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20test%20%3D%20%22%3C--%22%0A%20%20%20%20%20%20%20%20%20%20%20%20test%20%3D%20test%20%2B%20str%28%20i%29%20%2B%20'3'%20%2B%20%22--%3E%22%20%2B%20str%28j%20//%203%29%0A%20%20%20%20%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20test%20%3D%20%22--%3E%22%0A%20%20%20%20%20%20%20%20%20%20%20%20test%20%3D%20%22--%3E%22%20%2B%20str%28%28i%20//%203%29%29%20%2B%20test%20%2B%20str%28j%29%0A%20%20%20%20%20%20%20%20print%28test%29%0A%20%20%20%20%20%20%20%20j%20-%3D1%0A%20%20%20%20i%2B%3D1&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %%
# Task 15

i=0
j=0
k=15
test = '<--cat'
while i < 5:
    k -= 1
    j = k
    while j > 10:
        if j % 2 == 0:
            test += '-->'
            test = test + str(i) + str(j // 2)
        else:
            test += '<--'
            test = test + str(i // 2) + str(j)
        print(test)
        j-=1
    i+=1

# https://pythontutor.com/render.html#code=i%3D0%0Aj%3D0%0Ak%3D15%0Atest%20%3D%20'%3C--cat'%0Awhile%20i%20%3C%205%3A%0A%20%20%20%20k%20-%3D%201%0A%20%20%20%20j%20%3D%20k%0A%20%20%20%20while%20j%20%3E%2010%3A%0A%20%20%20%20%20%20%20%20if%20j%20%25%202%20%3D%3D%200%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20test%20%2B%3D%20'--%3E'%0A%20%20%20%20%20%20%20%20%20%20%20%20test%20%3D%20test%20%2B%20str%28i%29%20%2B%20str%28j%20//%202%29%0A%20%20%20%20%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20test%20%2B%3D%20'%3C--'%0A%20%20%20%20%20%20%20%20%20%20%20%20test%20%3D%20test%20%2B%20str%28i%20//%202%29%20%2B%20str%28j%29%0A%20%20%20%20%20%20%20%20print%28test%29%0A%20%20%20%20%20%20%20%20j-%3D1%0A%20%20%20%20i%2B%3D1&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %% [markdown]
# **Ungraded**

# %%
# Task 1
#

# %% [markdown]
# ***2nd Quiz*** (Oct 31, 2022)

# %% [markdown]
# ![313221993_509457431090959_3132583942792189928_n.jpg](data:image/jpeg;base64,...)

# %%
# usecases of index, and slice

a_string = '7462384951'
sliced = a_string[-(int(a_string[-4:8])% 10)]
print(sliced, type(sliced))

# %%
# concatenating

string1 = 'You useful on rainy days, Colonel.'
string2 = '\'re less rainy'
string3 = string1[:3]+string2[:3]+string1[3:7]+string2[4:-6:]+string1[10:]
print(string3)

# %% [markdown]
# ![313372221_648678343540137_7199037984689577472_n.jpg](data:image/jpeg;base64,...)

# %%
# finding string size (without using len())

count = 0

var = input()

for i in var:
  count+=1
print(count)

# %% [markdown]
# ![313492665_1054375325244092_2549746086216721825_n.jpg](data:image/jpeg;base64,...)

# %%
# string input will have alphabets and spaces
# checks if "small letters" are gradually increasing
# unique small letters are printed separately, and
# another string with ascii values get printed as well

small = ""  # stores the small alphabet
ascii = ""  # concatenates ascii value
ans = ""    # removes repeated alphabet
flag = True

S = input()

for e in S:
  if ord("a") <= ord(e) <= ord("z"):
    small += e

for i in range(len(small)-1):

  if ord(small[i]) < ord(small[i+1]): # increment / sequence checking
    ans += small[i]
    ascii += str(ord(small[i]))

  elif ord(small[i]) == ord(small[i+1]):
    continue # ignores the repeated alphabet

  else:
    print("Not increasing")
    flag = False
    break


if flag != False:
  print(ans)
  print(ascii)

# %% [markdown]
# **Mid** (Nov 04, 2022)

# %%
#Q1

num = input()
sum = 0
last_digit = int(num[-1])

for i in range(len(num)-1):
  sum += int(num[i])

if sum % 10 == last_digit:
  print("Match")
else:
  print("No Match")

# %% [markdown]
# **Lab Quiz** (Nov 17, 2022)

# %% [markdown]
# ![315313506_1119885448662068_8304980330674162958_n.jpg](data:image/jpeg;base64,...)

# %%
# takes two inputs — one <str>, one <int> type
# convert strings into ascii with ord() function and
# then utilize chr() — concatenate values; finally prints

chng_ord = 0
chng_chr = ''
encr_sen = ""

sen = input()
num = int(input())


for itr in sen:
  chng_ord = ord(itr) + num
  if chng_ord > 126:
    chng_ord -= 95
  chng_chr = chr(chng_ord)
  encr_sen += chng_chr

print("Encoded message: ", encr_sen)

# %% [markdown]
# ![311318260_2036362910084787_4487910660635979741_n.jpg](data:image/jpeg;base64,...)

# %%
# odd-even check, branching applied
# if math module not used, for loop required

# approach 01

# fact = 1
# new = 0

# num = int(input("Give one integer: "))
# if num % 2 != 0:
#   for itr in range(1, num+1):
#     fact = fact * itr
#   print(fact)
  
#   for itr in range(1, num+1):
#     new = str(num) '*' (num - itr)
#     print(num, '*', num-itr)
#     print(new + '!')


# approach 02
# using built in function

import math  
def fact(n):  
    return(math.factorial(n))  

factorial = 1
num = int(input("Give one integer: "))

if num < 0:
  print("Factorial does not exist negative values.")

elif num == 0:
  print("0!\n1")

elif num % 2 != 0:  # for odd input, bottom-up
  factorial = fact(num)
  print(factorial)

  for itr in range(1, num+1):
    while itr < num:
      print(str(num)+'*'+str(num-itr))
      itr+=1
      # print(str(num-1)+'*'+str(num-itr))

elif num % 2 == 0:  # for even input, top to bottom
  print(str(num)+'!')

  for itr in range(1, num+1):
    print(str(num)+'*'+str(num-itr)+'!')
  
  factorial = fact(num)
  print(factorial)


# https://www.geeksforgeeks.org/python-program-for-factorial-of-a-number/

# %%
# For y'all to be extra prepared, I had to play sneaky and get these question papers from not-so-trusted sources ...
# Solve 'em, already !! Should be easy. Bleh.

# Nowrin, hi. Next time hide your Name and ID, ttsskkkk :<

# %% [markdown]
# ![315495952_665604361796319_1229333076329731620_n.jpg](data:image/jpeg;base64,...)

# %%
# Here, Mahpara Momo Maisha (that's one individual btw) did a good job
# not mentioning her name but imma be saying it anyway, yeah :>
# nice nail polish, there ... LMAO

# %% [markdown]
# ![315526052_497081779148023_2914648596290601276_n.jpg](data:image/jpeg;base64,...)

# %%
# Q2
# Tracing

i = 1
h = 1
sum = 0

while i < 10:
    j = i * 15
    while j <= 25:
      k = i + j * 4 ** i + h + 3 % 2 ** h / 2 + sum
      sum = sum + 7

      if j % 2 == 0 or sum % 2 == 0:
        print(int(k))
      
      else:
        p = "-"
        p += str(j+sum) + "-->" + str(j)+'<--'
        print(p)
      j = j + 6 * j % 2 + j % 2 + 1
    print(j)
    i += j % 4 + 1

print(sum)

# https://pythontutor.com/render.html#code=i%20%3D%201%0Ah%20%3D%201%0Asum%20%3D%200%0A%0Awhile%20i%20%3C%2010%3A%0A%20%20%20%20j%20%3D%20i%20*%2015%0A%20%20%20%20while%20j%20%3C%3D%2025%3A%0A%20%20%20%20%20%20k%20%3D%20i%20%2B%20j%20*%204%20**%20i%20%2B%20h%20%2B%203%20%25%202%20**%20h%20/%202%20%2B%20sum%0A%20%20%20%20%20%20sum%20%3D%20sum%20%2B%207%0A%0A%20%20%20%20%20%20if%20j%20%25%202%20%3D%3D%200%20or%20sum%20%25%202%20%3D%3D%200%3A%0A%20%20%20%20%20%20%20%20print%28int%28k%29%29%0A%20%20%20%20%20%20%0A%20%20%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20p%20%3D%20%22-%22%0A%20%20%20%20%20%20%20%20p%20%2B%3D%20str%28j%2Bsum%29%20%2B%20%22--%3E%22%20%2B%20str%28j%29%2B'%3C--'%0A%20%20%20%20%20%20%20%20print%28p%29%0A%20%20%20%20%20%20j%20%3D%20j%20%2B%206%20*%20j%20%25%202%20%2B%20j%20%25%202%20%2B%201%0A%20%20%20%20print%28j%29%0A%20%20%20%20i%20%2B%3D%20j%20%25%204%20%2B%201%0A%0Aprint%28sum%29%0A&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false
