# %% [markdown]
# <a href="https://colab.research.google.com/github/SiliconJelly/BRACU/blob/main/CSE110%20(NZF)/LAB%2002%20(Oct%2013%202022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (2nd lab) from these tasks, at CSE110 — 
# we mainly test our knowledge about "BRANCHING"

'''
  if this if that, elif?
  then we have else, or
  booleans, maybe? and,
  what not? Conditionals!
'''

  # DOC link for the task sets:
  # https://docs.google.com/document/d/1jyNUc1WfqDjeEr5QsxzF2fMwsJjicEUf

# %% [markdown]
# ![maxresdefault.jpg](data:image/jpeg;base64,...)

# %%
#Task 01

m = int(input())
n = int(input())

print("Sum =", m+n)
print("Product =" ,m*n)
print("Difference =", m-n)

# %%
#Task 02

from math import pi

rad = float(input())
area = pi * rad**2
circum = 2* pi * rad

print("Area is", area)
print("Circumference is", circum)

# %%
#Task 03

m = int(input())
n = int(input())

if m > n:
  print("First is greater")
else:
  print("Second is greater")

# %%
#Task 04

m = int(input())
n = int(input())

if m > n:
  print(m-n)
else:
  print(n-m)

# %%
#Task 05

i = int(input())

if i % 2 ==0:
  print("The number is even")
else:
  print("The number is odd")

# %%
#Task 06

i = int(input())

if i % 2 ==0 or i % 5 ==0:
  print(i)
else:
  print("Not a multiple of 2 OR 5")

# %%
#Task 07

i = int(input())

if i % 2 ==0 and i % 5 ==0:
  print("Multiple of 2 and 5 both")
elif i % 2 ==0 or i % 5 ==0:
  print(i)
else:
  print("Not a multiple we want")

# %%
#Task 08

i = int(input())

if i % 2 ==0 and i % 5 ==0:
  print(i)
else:
  print("Not a multiple of 2 and 5 both")

# %%
#Task 09

sec = int(input())

hr = sec // 3600
sec = sec % 3600

min = sec // 60
sec = sec % 60

print("Hours:", hr, "Minutes:", min, "Seconds:", sec)

# %%
#Task 10

sal = 8000
i = int(input())

if i >= 40 and i <= 168:
  print(sal + (i-40)*300)
elif i > 0 and i < 40:
  print(i*200)
elif i > 168:
  print("Impossible to work more than 168 hours weekly")
elif i < 0:
  print("Hour cannot be negative")

# %%
#Task 11

S = int(input())

if S < 100:
  L = 3000 - 125*S**2
  print(L)

else:
  L = 12000 / (4+S**2/14900)
  print(L)

# %%
#Task 12

i = int(input())

if i in range(4,7):
    print("Breakfast")
elif i in range(12,14):
    print("Lunch")
elif i in range(16,18):
    print("Snack")
elif i in range(19,21):
    print("Dinner")
else:
    if i in range(0,25):
      print("Patience is virtue")
    else:
      print("Wrong time")

# %%
#Task 13

i = int(input())

if i in range(90,101):
    print("A")
elif i in range(80,90):
    print("B")
elif i in range(70,80):
    print("C")
elif i in range(60,70):
    print("D")
elif i in range(50,60):
    print("E")
elif i in range(0,50):
    print("F")
else:
    print("Invalid input")

# %%
#Task 14

d = int(input())
t = int(input())
v = (d/1000)/(t/3600)
print(v, "km/h")

#problem with test case 2, skips the if block — when range() is used
#if v in range(0,60):

if v >= 0 and v < 60:
    print("Too slow. Needs more changes.")
elif v in range(60,91):
    print("Velocity is okay. The car is ready!")
elif v > 90:
    print("Too fast. Only a few changes should suffice.")
else:
    print("Wrong input: Try Again")

# %%
#Task 15

cg = float(input())
cred = int(input())

if cred < 30:
  print("The student is not eligible for a waiver")
elif cg >= 3.80 and cg <= 3.89:
  print("The student is eligible for a waiver of 25 percent.")
elif cg >= 3.90 and cg <= 3.94:
  print("The student is eligible for a waiver of 50 percent.")
elif cg >= 3.95 and cg <= 3.99:
  print("The student is eligible for a waiver of 75 percent.")
elif cg == 4.00:
  print("The student is eligible for a waiver of 100 percent.")
else:
  print("The student is not eligible for a waiver")

# %% [markdown]
# Tracing (**Introduction**)
#
# ![Tracing.JPG](data:image/jpeg;base64,...)

# %%
print("A recent Harvard study found that, the top reason for any CSE student to say \"BBA would've been a better choice\" is probably because, this Tracing thingy!")

# %%
# Task 16
# BRAC wants you to stop thinking about the permanent campus, and start thinking like a computer!!

# This is your first tracing, so stop screaming like a child, and start already.
# Tracing is your translation of the given code; you being the interpreter ;) !!

p = 5
q = 6
r = 9
sum = 0
if (p < 12):
    print(r + 2)
else:
    print(r + p)
if (q > 20):
    print(r + 19)
elif (q <= 6):
    print(q + 3)
else:
    print(p + q + r)
if (r > 15):
    print(r)
elif (r == 0):
    print(p + q)
else:
    print(p)
if (sum != 0):
    print(3)
else:
    print(sum + 32)

'''
|var| p | q | r | sum |
=======================
|inp| 5 | 6 | 9 |  0  | 
_______________________

|       Output         |
========================
|inp| 5 | 6 | 9 |  0   |
|ans| 11| 9 | 5 |  14  |
'''

# solution: https://pythontutor.com/visualize.html#code=x%20%3D%200%0Ap%20%3D%200%0Asum%20%3D%200%0Ap%20%3D%201%0Ax%20%3D%202%0Aq%20%3D%200.0%0Asum%20%3D%200%0Awhile%20%28p%20%3C%2010%29%20%3A%0A%20%20q%20%3D%20x%20%2B%20p%20-%20%28sum%20%2B%20int%285%20/%203%29%29%20/%203.0%20%25%202%0A%20%20sum%20%3D%20sum%20%2B%20x%20%2B%20int%28q%29%0A%20%20x%20%2B%3D%201%0A%20%20print%28sum%29%0A%20%20if%20%28x%20%3E%205%29%20%3A%0A%20%20%20%20p%20%2B%3D%20int%284%20/%202%29%0A%20%20else%20%3A%0A%20%20%20%20p%20%2B%3D%203%20%25%201%0Asum%20%3D%20sum%20%2B%20p%0Aprint%28sum%29%0Aif%20%28p%3E0%20and%20r%3C10%29%3A%0A%20%20%20%20print%28p%2Br%29%0Aelse%3A%0A%20%20%20%20print%28p-r%29&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false
# Protip: Always keep your eyes on variables, their changes throughout conditional influence, and print/output.

# %%
# Above you see a demonstration, which was totally unnecessary — waste of time, maybe?
# Well on the other hand your whole CSE dream is a waste of lots of energy, so I guess, this wasn't that bad ...
# But whatever, I would highly suggest relying on PythonTutor, you can even bookmark that, here's the link:
# https://pythontutor.com/python-debugger.html#mode=edit

# From now on, most of your lab shall contain tracing part in the bottom
# It's always wise to take tracing codes on any IDE, and run YOUR VERSION first
# Compare your simulation VS pythontutor's solution, step by step
# For the tracings, I shall paste direct links to the visualization tab ...
# Yes, this is me being nice to you for the 69th time today, so yeah! Bleh ...

# %%
# Task 17

var1 = var2 = var3 = var4 = var5 = var6 = False
result1 = False
result2 = False
result3 = False
result4 = False
result5 = False
result6 = False
result7 = False
result8 = False
result9 = False
result10 = False
var1 = 4 > 3 - 1
var2 = var1 and False
var3 = True
var4 = False
var5 = True
var6 = var3 and False
result1 = (var1 or var2) and (8 * 10 > 45)
result2 = (var1 or var2) and (result1 and False)
result3 = (var1 and result1) or result2
result4 = (var1 or var2) or ((var3 and var1) and False)
result5 = (var1 and var2) and (result3 or var1)
result6 = ((var3 or var2) and not(result5)) or True
result7 = (var4 and result1) and ((result1 and False) or True)
result8 = ((var1 and result3) and (var5 or var6)) and True
result9 = ((result2 and var2) or (result7 and var1)) and False
result10 = not(var1 and True)

# https://pythontutor.com/visualize.html#code=var1%20%3D%20var2%20%3D%20var3%20%3D%20var4%20%3D%20var5%20%3D%20var6%20%3D%20False%0Aresult1%20%3D%20False%0Aresult2%20%3D%20False%0Aresult3%20%3D%20False%0Aresult4%20%3D%20False%0Aresult5%20%3D%20False%0Aresult6%20%3D%20False%0Aresult7%20%3D%20False%0Aresult8%20%3D%20False%0Aresult9%20%3D%20False%0Aresult10%20%3D%20False%0Avar1%20%3D%204%20%3E%203%20-%201%0Avar2%20%3D%20var1%20and%20False%0Avar3%20%3D%20True%0Avar4%20%3D%20False%0Avar5%20%3D%20True%0Avar6%20%3D%20var3%20and%20False%0Aresult1%20%3D%20%28var1%20or%20var2%29%20and%20%288%20*%2010%20%3E%2045%29%0Aresult2%20%3D%20%28var1%20or%20var2%29%20and%20%28result1%20and%20False%29%0Aresult3%20%3D%20%28var1%20and%20result1%29%20or%20result2%0Aresult4%20%3D%20%28var1%20or%20var2%29%20or%20%28%28var3%20and%20var1%29%20and%20False%29%0Aresult5%20%3D%20%28var1%20and%20var2%29%20and%20%28result3%20or%20var1%29%0Aresult6%20%3D%20%28%28var3%20or%20var2%29%20and%20not%28result5%29%29%20or%20True%0Aresult7%20%3D%20%28var4%20and%20result1%29%20and%20%28%28result1%20and%20False%29%20or%20True%29%0Aresult8%20%3D%20%28%28var1%20and%20result3%29%20and%20%28var5%20or%20var6%29%29%20and%20True%0Aresult9%20%3D%20%28%28result2%20and%20var2%29%20or%20%28result7%20and%20var1%29%29%20and%20False%0Aresult10%20%3D%20not%28var1%20and%20True%29&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %%
# Task 18

var1 = False
var2 = False
var3 = False
var4 = False
var5 = False
var6 = False
result1 = False
result2 = False
result3 = False
result4 = False
result5 = False
result6 = False
result7 = False
result8 = False
result9 = False
result10 = False
var1 = ((not True) or True) and False
var2 = var1 and False
var3 = True and not False
var4 = False
var5 = True
var6 = var3 and False
result1 = (var1 and var2) and (40 % 3) > 45 or (var5 and var6)
result2 = (var1 or var2) or (result1 and False)
result3 = (var1 and result1) or result2 or var5
result4 = (var1 or var2) or ((var3 and var1) and False)
result5 = (var1 and var2) and (result3 or var1)
result6 = ((var3 or (not var2)) and (result5)) or True
result7 = (var4 and result1) and ((result1 and False) or True)
result8 = ((var1 and result3) and ((not var5) or var6)) and True
result9 = ((result2 and var2) or ((not result7) and var1)) and not False
result10 = not(var1 and True)

# https://pythontutor.com/visualize.html#code=var1%20%3D%20False%0Avar2%20%3D%20False%0Avar3%20%3D%20False%0Avar4%20%3D%20False%0Avar5%20%3D%20False%0Avar6%20%3D%20False%0Aresult1%20%3D%20False%0Aresult2%20%3D%20False%0Aresult3%20%3D%20False%0Aresult4%20%3D%20False%0Aresult5%20%3D%20False%0Aresult6%20%3D%20False%0Aresult7%20%3D%20False%0Aresult8%20%3D%20False%0Aresult9%20%3D%20False%0Aresult10%20%3D%20False%0Avar1%20%3D%20%28%28not%20True%29%20or%20True%29%20and%20False%0Avar2%20%3D%20var1%20and%20False%0Avar3%20%3D%20True%20and%20not%20False%0Avar4%20%3D%20False%0Avar5%20%3D%20True%0Avar6%20%3D%20var3%20and%20False%0Aresult1%20%3D%20%28var1%20and%20var2%29%20and%20%2840%20%25%203%29%20%3E%2045%20or%20%28var5%20and%20var6%29%0Aresult2%20%3D%20%28var1%20or%20var2%29%20or%20%28result1%20and%20False%29%0Aresult3%20%3D%20%28var1%20and%20result1%29%20or%20result2%20or%20var5%0Aresult4%20%3D%20%28var1%20or%20var2%29%20or%20%28%28var3%20and%20var1%29%20and%20False%29%0Aresult5%20%3D%20%28var1%20and%20var2%29%20and%20%28result3%20or%20var1%29%0Aresult6%20%3D%20%28%28var3%20or%20%28not%20var2%29%29%20and%20%28result5%29%29%20or%20True%0Aresult7%20%3D%20%28var4%20and%20result1%29%20and%20%28%28result1%20and%20False%29%20or%20True%29%0Aresult8%20%3D%20%28%28var1%20and%20result3%29%20and%20%28%28not%20var5%29%20or%20var6%29%29%20and%20True%0Aresult9%20%3D%20%28%28result2%20and%20var2%29%20or%20%28%28not%20result7%29%20and%20var1%29%29%20and%20not%20False%0Aresult10%20%3D%20not%28var1%20and%20True%29&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %%
# Task 19

var1 = var2 = var3 = var4 = var5 = var6 = False 
result1 = result2 = result3 = result4 = result5 = result6 = False
result7 = result8 = result9 = result10 = False
var1 = (not False or False) and True
var2 = var1 and True
var3 = False and not True
var4 = True
var5 = False
var6 = var3 and True
result1 = (var1 and var2) and ( 40 % 3 > 45) or (var5 and var6)
result2 = (var1 or var2) or (result1 and False)
result3 = (var1 and result1) or result2 or var5
result4 = (var1 or var2) or ((var3 and var1) and False)
result5 = (var1 and var2) and (result3 or var1)
result6 = ((var3 or not var2) and (result5)) or True
result7 = (var4 and result1) and ((result1 and False) or True)
result8 = ((var1 and result3) and (not var5 or var6)) and True
result9 = ((result2 and var2) or (not result7 and var1)) and not False
result10 = not (var1 and True)

# https://pythontutor.com/visualize.html#code=var1%20%3D%20var2%20%3D%20var3%20%3D%20var4%20%3D%20var5%20%3D%20var6%20%3D%20False%20%0Aresult1%20%3D%20result2%20%3D%20result3%20%3D%20result4%20%3D%20result5%20%3D%20result6%20%3D%20False%0Aresult7%20%3D%20result8%20%3D%20result9%20%3D%20result10%20%3D%20False%0Avar1%20%3D%20%28not%20False%20or%20False%29%20and%20True%0Avar2%20%3D%20var1%20and%20True%0Avar3%20%3D%20False%20and%20not%20True%0Avar4%20%3D%20True%0Avar5%20%3D%20False%0Avar6%20%3D%20var3%20and%20True%0Aresult1%20%3D%20%28var1%20and%20var2%29%20and%20%28%2040%20%25%203%20%3E%2045%29%20or%20%28var5%20and%20var6%29%0Aresult2%20%3D%20%28var1%20or%20var2%29%20or%20%28result1%20and%20False%29%0Aresult3%20%3D%20%28var1%20and%20result1%29%20or%20result2%20or%20var5%0Aresult4%20%3D%20%28var1%20or%20var2%29%20or%20%28%28var3%20and%20var1%29%20and%20False%29%0Aresult5%20%3D%20%28var1%20and%20var2%29%20and%20%28result3%20or%20var1%29%0Aresult6%20%3D%20%28%28var3%20or%20not%20var2%29%20and%20%28result5%29%29%20or%20True%0Aresult7%20%3D%20%28var4%20and%20result1%29%20and%20%28%28result1%20and%20False%29%20or%20True%29%0Aresult8%20%3D%20%28%28var1%20and%20result3%29%20and%20%28not%20var5%20or%20var6%29%29%20and%20True%0Aresult9%20%3D%20%28%28result2%20and%20var2%29%20or%20%28not%20result7%20and%20var1%29%29%20and%20not%20False%0Aresult10%20%3D%20not%20%28var1%20and%20True%29&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %% [markdown]
# **Ungraded**

# %%
# Task 20

num = int(input())

if num % 2 != 0 and num % 5 != 0:
  print(num)
  
else:
  print("No")

# %%
# Task 21

num = int(input())

if num % 2 != 0 or num % 5 != 0:
  print(num)

else:
  print("No")

# %%
# Task 22

canvas_price = 120
paint_price = 75
discount = 0

canvas_amount = int(input())
paint_amount = int(input())

total = (canvas_price * canvas_amount) + (paint_price * paint_amount)

if total >= 0 and total <= 299:
# if 0 >= total <= 299:
  discount = 0

elif 300 >= total <= 499:
  discount = 10

elif 500 >= total <= 749:
  discount = 20

elif 750 >= total <= 999:
  discount = 50

else:
  discount = 150


print("Previous total:", total)
print("New total after discount:", total - discount)

# %%
# Task 23

Season = ''
Fahrenheit = int(input())
Celsius = int((Fahrenheit - 32) * 0.56)

if Celsius < 20:
  Season = "Winter"

elif 20 <= Celsius <= 25:
  Season = "Autumn"

elif 25 < Celsius < 30:
  Season = "Spring"

elif Celsius >= 30:
  Season = "Summer"


print(Celsius, "degrees C")
print(Season)
