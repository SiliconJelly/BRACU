# %% [markdown]
# <a href="https://colab.research.google.com/github/SiliconJelly/BRACU/blob/main/CSE110%20(NZF)/LAB%2003%20(Oct%2020%202022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (3rd lab) from these tasks, at CSE110 — 
# we mainly test our knowledge about "LOOPS"

count = 1
while count <= 5:
  print("CSE")
  count = count+1
  if count == 3:
    continue
  print("110")
  print("=====")
  count = count + 1

 
  # DOC link for the task sets:
  # https://docs.google.com/document/d/1ctS8Y58j0nXVwVutB_H39FD9Qb7saMwF

# %% [markdown]
# ![pjc0u3ygir541.jpg](data:image/jpeg;base64,...)

# %%
# Task 01
# a) 24, 18, 12, 6, 0, -6

# initialize loop counter
count = 24

# loop structure
while count >= -6:

  #inside loop body
  if count == -6:
    print(count, end = "")
  else:
    print(count, end = ", ")
    
  count -= 6 #updating loop counter
  #inside loop body
  
#outside loop body

# %%
# Task 01
# b) -10, -5, 0, 5, 10, 15, 20

count = -10

while count <= 20:


  if count == 20:
    print(count, end = "")
  else:
    print(count, end = ", ")
    
  count += 5

# %%
# Task 01
# c) 18, 27, 36, 45, 54, 63

count = 18

while count <= 63:


  if count == 63:
    print(count, end = "")
  else:
    print(count, end = ", ")
    
  count += 9

# %%
# Task 01
# d) 18, -27, 36, -45, 54, -63
# aprroach 01

count = 18

while count <= 63:

  if count == 63:
    print(count * -1, end = "")
  elif count % 2 != 0:
    print(count * -1, end = ", ")
  else:
    print(count, end = ", ")
    
  count += 9


# approach 02
# using range() in for loop

# for i in range(18, 64, 9): 
#   if i % 2 == 0: 
#     print(i, end = ", ")
#   else: 
#     if i == 63:
#         print(-i, end = "")
#     else:
#         print(-i, end = ", ")

# %%
# Task 02
# approach 1

name = input()
num = int(input())

count = 1
while count <= num:
  print(name)
  count += 1


# approach 02 (concat_str)
#name = input()
#i = int(input())
#print(name*"\n",i)

# %%
# Task 03

sum = 0
for i in range(63, 601):
  if i % 7 ==0 and i % 9 ==0:
    sum += i
print(sum)

# %%
# Task 04

sum = 0
for i in range(0, 601):
  if i % 7 == 0 and i % 9 == 0:
    continue
  elif i % 7 == 0 or i % 9 == 0:
    sum += i
print(sum)

# %%
# Task 05

for i in range(10,51):
  if i % 2 != 0:
    print(i, end = " ")
  i += 2

# %%
# Task 06

n = int(input())
sum = 0

for i in range(n + 1):
  if i % 2 == 0:
    sum -= i*i
  else:
    sum += i*i

print(sum)

# %%
# Task 07

total = 0 
count = 0 

for i in range(0, 10): 
  num = int(input()) 
  if num % 2 != 0: 
    total += num 
    count += 1

print("The total of the odd number is ", total, "and their average is ",total/count)

# %%
# Task 08

sum = 0
N = int(input())

for i in range(N+1):
  if i % 7 == 0:
    sum += i
print(sum)

# %%
# Task 09

sum = 0

for i in range(0,5):
  num = int(input())
  sum += num
  print(sum)

# %%
# Task 10

count = 0

num = int(input())
for i in range(num + 1):

  count = num % 10 
  print(count, end=", ")

  num //= 10

  if num < 10:
    print(num, end = "")
    break

# %%
# Task 11

count = 0

num = int(input())
while num > 0:     # can't use for loop, because
  num //= 10       # for loop relies on range()
  count += 1       # and range needs len as arg*

print(count)


# but the program will give a zero if
# input is zero, stead of digit count (1)
# we can fix this with break and if statements

# %%
# Task 12
# approach 01

val = int(input())
num = val
for itr in range(num):
  if num // 10 == 0:
    itr += 1
    break
  else:
    num //= 10
    itr += 1

while itr >= 1:
  if val // 10 == 0:
    print(val, end='')
    break

  else:
    sep = val // (10 ** (itr - 1))
    val = val % (10 ** (itr- 1))
  
  print(sep, end = ',')
  itr -= 1


# approach 02
# simple, wehen used string (or list)

# num = int(input())
# num_str = str(num)
# for num in num_str:
#   print(int(num), end = ", ")

# %%
# Task 13

count = 0

num = int(input())

for div in range(1, num+1):
  
  if num % div == 0:
    count += 1
    print(div)

print("Total", count, "divisors.")

# %%
# Task 14

sum = 0
num = int(input())

for div in range(1, num+1):
   if num % div == 0:
    sum += div

if sum - num == num:
  print(num, "is a perfect number")
else:
  print(num, "is not a perfect number")

# %%
# Task 15

count = 0

num = int(input())

for div in range(1, num+1):
  if num % div == 0:
    count += 1
    
if count == 2:
  print(num, "is a prime number")

else:
  print(num, "is not a prime number")

# %%
# Task 16

sum = 0
count = 0
temp = 0
max = 0
min = 0

quant = int(input())

for num in range(1, quant+1):
  val = int(input())

  count += 1
  sum += val

  if val > temp and val > max:
    max = val

  if val < temp and val < min:
    min = val

  temp = val

print("Maximum", max)
print("Minimum", min)
print("Average is", sum/count)

# %%
# Task 17
# approach 01
# using str() concatenation

# N = int(input())

# for num in range(1, N+1):
#     print("+" * N)

# approach 02
# using two for loops

n=int(input())
row="+"
for i in range(n-1):
  row=row+"+"
for i in range(n):
  print(row)

# %%
# Task 18

M = int(input())
N = int(input())

for num in range(1, M+1):

  for num in range(1, N+1):
    if num == N:  # not using break, repeats
      break       # the last digit >> 1234566
    print(num, end ="")

  print(num)
  num += 1

# %%
# Task 19

N = int(input())

for row in range(1, N+1):
  for col in range(1, row+1):
    print(col, end="")
  
  print()

# https://youtu.be/0PkIvXfP3ew

# %% [markdown]
# Tracing

# %%
# Task 20

x = 0
p = 0
sum = 0
p = 1
x = 2
q = None
sum = 0

while p < 12:
    q = x + p - (sum + 7 / 3) / 3.0 % 2
    sum = sum + x + int(q)
    x += 1
    print(sum)

    if x > 5:
        p += 4 / 2
    else:
        p += (3 % 1)

sum = int(sum + p)
print(sum)

# https://pythontutor.com/render.html#code=x%20%3D%200%0Ap%20%3D%200%0Asum%20%3D%200%0Ap%20%3D%201%0Ax%20%3D%202%0Aq%20%3D%20None%0Asum%20%3D%200%0A%0Awhile%20p%20%3C%2012%3A%0A%20%20%20%20q%20%3D%20x%20%2B%20p%20-%20%28sum%20%2B%207%20/%203%29%20/%203.0%20%25%202%0A%20%20%20%20sum%20%3D%20sum%20%2B%20x%20%2B%20int%28q%29%0A%20%20%20%20x%20%2B%3D%201%0A%20%20%20%20print%28sum%29%0A%0A%20%20%20%20if%20x%20%3E%205%3A%0A%20%20%20%20%20%20%20%20p%20%2B%3D%204%20/%202%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20p%20%2B%3D%20%283%20%25%201%29%0A%0Asum%20%3D%20int%28sum%20%2B%20p%29%0Aprint%28sum%29%0A&cumulative=false&curInstr=73&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %%
# Task 21

x = 0
p = 0
sum = 0
p = 1
x = 2
q = 0.0
sum = 0
while (p < 10) :
  q = x + p - (sum + int(5 / 3)) / 3.0 % 2
  sum = sum + x + int(q)
  x += 1
  print(sum)
  if (x > 5) :
    p += int(4 / 2)
  else :
    p += 3 % 1
sum = sum + p
print(sum)
if (p>0 and r<10):
    print(p+r)
else:
    print(p-r)

# https://pythontutor.com/render.html#code=x%20%3D%200%0Ap%20%3D%200%0Asum%20%3D%200%0Ap%20%3D%201%0Ax%20%3D%202%0Aq%20%3D%200.0%0Asum%20%3D%200%0Awhile%20%28p%20%3C%2010%29%20%3A%0A%20%20q%20%3D%20x%20%2B%20p%20-%20%28sum%20%2B%20int%285%20/%203%29%29%20/%203.0%20%25%202%0A%20%20sum%20%3D%20sum%20%2B%20x%20%2B%20int%28q%29%0A%20%20x%20%2B%3D%201%0A%20%20print%28sum%29%0A%20%20if%20%28x%20%3E%205%29%20%3A%0A%20%20%20%20p%20%2B%3D%20int%284%20/%202%29%0A%20%20else%20%3A%0A%20%20%20%20p%20%2B%3D%203%20%25%201%0Asum%20%3D%20sum%20%2B%20p%0Aprint%28sum%29&cumulative=false&curInstr=66&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %%
# Task 22

x = y = 0 
sum = 0
while (x < 10):
  y = x - 3
  while (y < 3):
    sum = x - y * 2 
    print(sum)
    y = y + 1
  if (x > 7): 
    x += 1
  else: 
    x += 3
sum = x - y * 2
print(sum)

# https://pythontutor.com/render.html#code=x%20%3D%20y%20%3D%200%20%0Asum%20%3D%200%0Awhile%20%28x%20%3C%2010%29%3A%0A%20%20y%20%3D%20x%20-%203%0A%20%20while%20%28y%20%3C%203%29%3A%0A%20%20%20%20sum%20%3D%20x%20-%20y%20*%202%20%0A%20%20%20%20print%28sum%29%0A%20%20%20%20y%20%3D%20y%20%2B%201%0A%20%20if%20%28x%20%3E%207%29%3A%20%0A%20%20%20%20x%20%2B%3D%201%0A%20%20else%3A%20%0A%20%20%20%20x%20%2B%3D%203%0Asum%20%3D%20x%20-%20y%20*%202%0Aprint%28sum%29&cumulative=false&curInstr=61&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %%
# Task 23

x = 0
y = 0
sum = 0
p = 0.0
while (x < 10):
    y = x // 2
    while (y < x):
        p = (x + 10.0) / 2
        sum = (sum % 2) + x - y * 2 + int(p)
        print(sum)
        y = y + 2
    if (x > 5):
        x += 1
    else:
        x += 2

# https://pythontutor.com/render.html#code=x%20%3D%200%0Ay%20%3D%200%0Asum%20%3D%200%0Ap%20%3D%200.0%0Awhile%20%28x%20%3C%2010%29%3A%0A%20%20%20%20y%20%3D%20x%20//%202%0A%20%20%20%20while%20%28y%20%3C%20x%29%3A%0A%20%20%20%20%20%20%20%20p%20%3D%20%28x%20%2B%2010.0%29%20/%202%0A%20%20%20%20%20%20%20%20sum%20%3D%20%28sum%20%25%202%29%20%2B%20x%20-%20y%20*%202%20%2B%20int%28p%29%0A%20%20%20%20%20%20%20%20print%28sum%29%0A%20%20%20%20%20%20%20%20y%20%3D%20y%20%2B%202%0A%20%20%20%20if%20%28x%20%3E%205%29%3A%0A%20%20%20%20%20%20%20%20x%20%2B%3D%201%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20x%20%2B%3D%202&cumulative=false&curInstr=95&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %%
# Task 24

test = 1
j = 0
k = 100
while (k > 0):
  while ( j < k ):
    test = k + j -21
    print(str(1 + int (test / 2)))
    j += 10
  k -= 10
test = 1
j = 0
k = 100

# https://pythontutor.com/render.html#code=test%20%3D%201%0Aj%20%3D%200%0Ak%20%3D%20100%0Awhile%20%28k%20%3E%200%29%3A%0A%20%20while%20%28%20j%20%3C%20k%20%29%3A%0A%20%20%20%20test%20%3D%20k%20%2B%20j%20-21%0A%20%20%20%20print%28str%281%20%2B%20int%20%28test%20/%202%29%29%29%0A%20%20%20%20j%20%2B%3D%2010%0A%20%20k%20-%3D%2010%0Atest%20%3D%201%0Aj%20%3D%200%0Ak%20%3D%20100&cumulative=false&curInstr=69&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false

# %% [markdown]
# **Ungraded**

# %%
# Task 25
# Program to display the Fibonacci sequence up to N-th term

nterms = int(input())

# first two terms
n1, n2 = 0, 1
count = 0

if nterms <= 0:
# check if the number of terms is valid
   print("Please enter a positive integer")

elif nterms == 1:
# if there is only one term, return n1
   print("Fibonacci sequence upto",nterms,"is :", n1)

else:
# generate fibonacci sequence
   while count < nterms:
      if n1 < nterms:
        print(n1, end =' ')
      
      new = n1 + n2
      # update values
      n1 = n2
      n2 = new
      count += 1
# Out:
# 15
# 0 1 1 2 3 5 8 13

# %%
# Task 26
#

# %%
# Task 27
#

# %%
# Task 28
#

# %%
# Task 29
#
