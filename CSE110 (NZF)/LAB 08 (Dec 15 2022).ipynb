# %% [markdown]
# <a href="https://colab.research.google.com/github/SiliconJelly/BRACU/blob/main/CSE110%20(NZF)/LAB%2008%20(Dec%2015%202022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (8th lab) from these tasks, at CSE110 — 
# we mainly test our knowledge about "SORTING"

print("Before you write a single line of code to deal with sorting problems,")
print("you are requested to watch this video at least once:"   "👇👇👇👇👇👇👇👇👇👇👇👇👇👇" )
                                                              # https://youtu.be/RGuJga2Gl_k
  
  # DOC link for the task sets:
  # https://docs.google.com/document/d/1PMVRJgkVLSxXr5gMr6t6Tmmg-uJ6NUSJ

print("Don't get demotivated when some say you won't need 'em irl; jUsT tRuSt ThE pRoCeSs!!")

# %% [markdown]
# ![thumb_when-you-finally-get-a-developer-job-but-they-say-62241480.png](data:image/png;base64,...)

# %%
# Task 01

def bubbleSortAscending(lst):
    for i in range(len(lst)):
        for j in range(len(lst)-1-i):
            if lst[j+1] < lst[j]:
                temp = lst[j] 
                lst[j] = lst[j+1]
                lst[j+1] = temp
    return lst

list1 = [10, 1, 20, 3, 6, 2, 5, 11, 15, 2, 12, 14, 17, 18, 29]

print(bubbleSortAscending(list1))

# %%
# Task 02

def selectionSortAscending(lst):
    for curr_i in range(len(lst)):
        min_i = curr_i
        for j in range(curr_i+1, len(lst)):
            if lst[j] < lst[min_i]:
                min_i = j
        temp = lst[curr_i] 
        lst[curr_i] = lst[min_i]
        lst[min_i] = temp
    return lst

my_list= [10, 1, 20, 3, 6, 2, 5, 11, 15, 2, 12, 14, 17, 18, 29]

print(selectionSortAscending(my_list))

# %%
# Task 03

def bubbleSortDescending(lst):
    for i in range(len(lst)):
        for j in range(len(lst)-1-i):
            if lst[j+1] > lst[j]:
                temp = lst[j] 
                lst[j] = lst[j+1]
                lst[j+1] = temp
    return lst

list1 = [10, 1, 20, 3, 6, 2, 5, 11, 15, 2, 12, 14, 17, 18, 29]

print(bubbleSortDescending(list1))

# %%
# Task 04

sitting_list = [10,30,20,70,11,15,22,16,58,100,12,56,70,80]

for i in range(len(sitting_list)):
    for j in range(i+2,len(sitting_list),2):
        if i%2==0 and j%2==0:
            if sitting_list[i] > sitting_list[j]:
                sitting_list[i], sitting_list[j] = sitting_list[j], sitting_list[i]

for m in range(len(sitting_list)):
    for n in range(m+2,len(sitting_list),2):
        if m%2!=0 and n%2!=0:
            if sitting_list[m] < sitting_list[n]:
                sitting_list[m], sitting_list[n] = sitting_list[n], sitting_list[m]

print(sitting_list)

# %%
# Task 05

def sort_students(course, students):
  # Create a dictionary with student names as keys and marks as values
  student_marks = {}
  for student in students:
    name = student[0]
    # Get the index of the course
    if course == "CSE110":
      index = 1
    elif course == "PHY111":
      index = 2
    elif course == "MAT110":
      index = 3
    # Add the student name and mark to the dictionary
    student_marks[name] = student[index]
  # Sort the dictionary in descending order based on the marks
  sorted_students = sorted(student_marks, key=student_marks.get, reverse=True)
  return sorted_students

# List of students
students = [ ["Alan", 95, 87, 91], ["Turing", 92, 90, 83], ["Elon", 87, 92, 80], ["Musk", 85, 94, 90] ]

# Take the course name as input from the user
course = input("Enter the course name: ")

# Call the function and print the sorted list of students
sorted_students = sort_students(course, students)
print(sorted_students)

# %%
# Task 06

def listsorting(My_list):
    count = 0
    for item in range(len(My_list)):
        min_index=item
        counter = 0
        for value in range(item+1,len(My_list)):
            if My_list[item]>value:
                min_index=value
                count+=1
        temp=value
        My_list[value]=My_list[item]
        My_list[item]=temp
    return count

lst = [4,2,3,1,2,10]

print(listsorting(lst))

# %%
# Task 07

inp1 = input()
inp1 = inp1[1:-1]
inp1 = inp1.split(", ")
list1 = []

for i in inp1:
    list1.append(int(i))
inp2 = input()
inp2 = inp2[1:-1]
inp2 = inp2.split(", ")
list2 = []

for j in inp2:
    list2.append(int(j))
new_list = list1 +list2
sorted_list = sorted(new_list)

print("Sorted list =", sorted_list)

mid = len(sorted_list) // 2
res = (sorted_list[mid] + sorted_list[~mid]) / 2

print("Median = ", int(res))

# %%
# Task 08

def find_closest_pairs(numbers):
  # Sort the list in ascending order
  numbers.sort()

  # Initialize variables to store the pairs with the smallest sum
  smallest_sum = float("inf")
  closest_pair = (0, 0)

  # Iterate through the list and find the pairs with the smallest sum
  for i in range(len(numbers) - 1):
    if abs(numbers[i] + numbers[i+1]) < smallest_sum:
      smallest_sum = abs(numbers[i] + numbers[i+1])
      closest_pair = (numbers[i], numbers[i+1])

  return "Two pairs which have the smallest sum = {} and {}".format(closest_pair[0], closest_pair[1])

# Test the function
list_one = [-10, 15, 2, 4, -4, 7, -8]
print(find_closest_pairs(list_one))

list_two = [1, -8, 4, -7, -20, 26, 70, -85]
print(find_closest_pairs(list_two))

# %%
# Task 09
# approach 01

import math

def find_closest_point(points):
  # Initialize variables to store the minimum distance and the closest point
  min_distance = float("inf")
  closest_point = (0, 0)

  # Iterate through the list of points and find the point with the minimum distance from the origin
  for point in points:
    distance = math.sqrt(point[0]**2 + point[1]**2)
    if distance < min_distance:
      min_distance = distance
      closest_point = point

  return "Minimum distance = {}\nHere the closest point is {} which has a distance of {} from the origin.".format(min_distance, closest_point, min_distance)

# Test the function
points_one = [(5,3), (2,9), (-2,7), (-3,-4), (0,6), (7,-2)]
print(find_closest_point(points_one))

points_two = [(1,7), (4,5), (-1,7), (-2,0), (1,1), (5,-1)]
print(find_closest_point(points_two))


# approach 02

# import math

# def distance(x,y):
#     distance = math.sqrt(x*x+y*y)
#     return distance

# points = [(1,7), (4,5), (-1,7), (-2,0), (1,1), (5,-1)]
# new_dis = []
# for i in points:
#     x,y = i
#     new_dis.append(distance(x,y))
# for i in range(len(new_dis)):
#     min_i = i
#     for j in range(i+1, len(new_dis)):
#         if new_dis[j] < new_dis[min_i]:
#             min_i = j
#     new_dis[i], new_dis[min_i] = new_dis[min_i], new_dis[i]
#     points[i], points[min_i] = points[min_i], points[i]

# print("Minimum distance =",new_dis[0])
# print("Here the closest point is", points[0], "which has a distance of",new_dis[0], "from the origin.")

# %%
print("And that's a wrap up for this semester, lads! Pop the confetti, and celebrate 🎉🥳 ...")
print("Hope this repository has been a help throughout your CSE110, and yeah, whoever is reading this,")
print("bbeesstt ooff lluucckk for your finals! Here here before you say goodbye, lemme code a donut for you: ")

                                                                        k;double sin() 
                                                                    ,cos();main(){float A= 
                                                                  0,B=0,i,j,z[1760];char b[ 
                                                                1760];printf("\x1b[2J");for(;; 
                                                              ){memset(b,32,1760);memset(z,0,7040) 
                                                              ;for(j=0;6.28>j;j+=0.07)for(i=0;6.28 
                                                            >i;i+=0.02){float c=sin(i),d=cos(j),e= 
                                                            sin(A),f=sin(j),g=cos(A),h=d+2,D=1/(c* 
                                                            h*e+f*g+5),l=cos      (i),m=cos(B),n=s\ 
                                                            in(B),t=c*h*g-f*        e;int x=40+30*D* 
                                                            (l*h*m-t*n),y=            12+15*D*(l*h*n 
                                                            +t*m),o=x+80*y,          N=8*((f*e-c*d*g 
                                                            )*m-c*d*e-f*g-l        *d*n);if(22>y&& 
                                                            y>0&&x>0&&80>x&&D>z[o]){z[o]=D;;;b[o]= 
                                                            ".,-~:;=!*#$@"[N>0?N:0];}}/*#****!!-*/ 
                                                              printf("\x1b[H");for(k=0;1761>k;k++) 
                                                              putchar(k%80?b[k]:10);A+=0.04;B+= 
                                                                0.02;}}/*****####*******!!=;:~ 
                                                                  ~::==!!!**********!!!==::- 
                                                                    .,~~;;;========;;;:~-. 
                                                                        ..,--------,*/ 

                                                        print(visit: https://tiny.one/SiliconJelly)
