# %% [markdown]
# <a href="https://colab.research.google.com/github/SiliconJelly/BRACU/blob/main/CSE110%20(NZF)/LAB%2007%20(Dec%2008%202022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (7th lab) from these tasks, at CSE110 — 
# we mainly test our knowledge about "FUNCTIONS"

print("If you still cannot define your career goals at BRAC-CS")
print("Well, you gotta learn how to def that shit now, child, or else ...")

  # DOC link for the task sets:
  # https://docs.google.com/document/d/14BqO2loKHwIjiW60sblko9l4NP7-N79k

print("*He's a Pirate plays in the background*")

# %% [markdown]
# ![EQYsmi-XUAIeE-Z.jpg](data:image/jpeg;base64,...)

# %%
# Task 01

def even_checker(num):
  
    if num %  == 0:
        print("Even!!")
    else:
        print("Odd!!")

even_checker(10)

# %%
# Task 02

def fibonacci(num):
    f_value = 0
    s_value = 1

    for i in range(num + 1):
        if f_value > num:
            break
            
        else:
            print(f_value, end = " ")
            next = f_value + s_value
            f_value = s_value
            s_value = next

fibonacci(10)

# %%
# Task 03

def foo_moo(num):
    if num % 2 == 0 and num % 3 == 0:
        print("FooMoo")
    elif num % 2 == 0:
        print("Foo")
    elif num % 3 == 0:
        print("Moo")
    else:
        print("Boo")
        
foo_moo(6)

# %%
# Task 04

def upperlower_counter(string):
    upper_count = 0
    lower_count = 0

    for i in string:
        if 65 <= ord(i) <= 90:
            upper_count += 1
        elif 97 <= ord(i) <= 122:
            lower_count += 1

    print("No of Uppercase characters: ", upper_count)
    print("No of Lowercase characters: ", lower_count)

upperlower_counter("The quick Sand Man")

# %%
# When you first discover that in Python a function can return multiple values

# %% [markdown]
# ![8x7eeiqo14t31.jpg](data:image/jpeg;base64,...)

# %%
# Task05

age = int(input("Enter your age: "))
salary = int(input("Enter your salary: "))
designation = input("Enter your Designation: ").lower()

def calculate_tax(age,salary,designation):
    if age < 18:
        print(0)
    else:
        if designation == "president":
            print(0)
        else:
            if salary < 10000:
                print(0)
            elif 10000 <= salary <= 20000:
                print(salary * 0.05)
            else:
                print(salary * 0.1)

calculate_tax(age, salary, designation)

# %%
# Task 06

def converter(num):
    year = num // 365
    rem = num % 365
    month = rem // 30
    rem = rem % 30
    print(f"{year} years, {month} months and {rem} days")

converter(4330)

# %%
# Task 07

def show_palindrome(num):
    for i in range(1, num+1):
        print(i, end="")
    for j in range(num-1, 0, -1):
        print(j, end="")
        
show_palindrome(5)

# %%
# Task 08

def show_palindrome(num):
    for i in range(1, num+1):
        print(i, end = " ")
    for j in range(num-1, 0, -1):
        print(j, end = " ")
    return ""

def show_palindrome_triangle(n):
    for i in range(1, n+1):
        print("  " * (n-i), end = "")
        print(str(show_palindrome(i)))
        
show_palindrome_triangle(5)

# %%
# Task 09

def area_circumference_generator(num):
    area = (22 / 7) * (num**2)
    circumference = 2 * (22 / 7) * num
    tup = area, circumference
    return tup

a = area_circumference_generator(1.5)
c, d = a

print(a)
print(f"Area of the circle is {c} and Circumference is {d}")

# %%
# Task 10

def make_square(r):
    dict1={}
    for i in range(r[0],r[1]+1):
        dict1[i]=i**2
    print(dict1)
    
make_square((1, 3))

# %%
# Task 11

def rem_duplicate(tup):
    t = list(tup)
    l = []
    
    for i in t:
        if i not in l:
            l.append(i)
    return tuple(l)

c = rem_duplicate(("Hi", 1, 2, 3, 3, "Hi",'a', 'a', [1,2]))
print(c)

# %%
# Task 12

def max2_list(l):
    new = []
    for i in l:
        if new.count(i)<2:
            new.append(i)

    print("Removed: ",len(l)-len(new))
    print(new)

max2_list([10, 10, 15, 15, 20])

# %%
# Task 13

def calculator(op,n1,n2):
    if op == "+":
        print(float(n1+n2))
    elif op == "-":
        print(float(n1-n2))
    elif op == "*":
        print(float(n1*n2))
    else:
        print(n1/n2)

op=input()
n1=float(input())
n2=float(input())
calculator(op,n1,n2)

# %%
# Task 14

s = input()
n = int(input())

def sentence_mixer(s,n):
    sto1 = ""
    sto2 = ""
    for i in range(len(s)):
        if i == 0:
            sto1 += s[i]
        elif i%n == 0:
            sto2 += s[i]
        else:
            sto1 += s[i]
    return sto1 + sto2

store = sentence_mixer(s,n)
print(store)

# %%
# Task 15

inp = input().strip("[]")
inp = inp.split(",")

def foodpanda(order, location = "Dhanmondi"):
    order_dict = {"Rice":105,"Potato":20,"Chicken":250,"Beef":510,"Oil":85}
    price=0
    
    for i in order:
            price += order_dict[i.strip('""')]
    if location == "Dhanmondi":
        price += 30
    else:
        price += 70
    return price

cost = foodpanda(inp,"Mohakhali")
print(cost)

# %% [markdown]
# **UNGRADED**

# %%
# Task 16

n = int(input())

def splitting_money(n):
    s = ""
    while True:
        if n > 0:
            if n >= 500:
                note = n//500
                a = "500 Taka: "+str(note)+" note(s)"
                n = n % 500
            elif 500 > n > = 100:
                note = n//100
                a = "100 Taka: "+str(note)+" note(s)"
                n = n % 100
            elif 100 > n > = 50:
                note = n//50
                a ="50 Taka: "+str(note)+" note(s)"
                n = n % 50
            elif 50 > n >= 20:
                note = n//20
                a = "20 Taka: "+str(note)+" note(s)"
                n = n % 20
            elif 20 > n >= 10:
                note = n//10
                a = "10 Taka: "+str(note)+" note(s)"
                n = n % 10
            elif 10 > n > = 5:
                note = n // 5
                a = "5 Taka: "+str(note)+" note(s)"
                n = n%5
            elif 5 > n >= 2:
                note = n //2
                a = "2 Taka: "+str(note)+" note(s)"
                n = n % 2
            else:
                note = n // 1
                a = "1 Taka: "+str(note)+" note(s)"
                n = n % 1
            s += f"{a}\n"
        else:
            break
    return s

sm = splitting_money(n)
print(sm)

# %%
# Task 17

def remove_odd(l):
    r_l = []
    for i in l:
        if i%2 == 0:
            r_l.append(i)
    return r_l
    
removed_odd_list = remove_odd([11,2,3,4,5,2,0,5,3])
print(removed_odd_list)

# %%
# Task 18

start = int(input())
end = int(input())
first_div = int(input())
second_div = int(input())

def divisible_total(a,b,c,d):
    total = 0
    for i in range(a,b):
        if i % c == 0 and i % d == 0:
            pass
        elif i % c == 0 or i%d==0:
            total += i
    return total

total = divisible_total(start,end,first_div,second_div)
print(total)

# %%
# Task 19

s=input().lower()

def psg(s):
    check = True
    l = ["a","b","c","d","e","f","g","h","i","j"]
    new = []
    for i in range(len(s)):
        if s[i] == " ":
            continue
        else:
            new.append(s[i])
    for i in l:
        if i in new:
            continue
        else:
            check = False
    return check
    
x = psg(s)
if x == True:
    for i in range(5):
        print("PSG will win the Champions League this season")
else:
    for i in range(6):
        print("PSG will win the Champions League this season")

# %%
# Task 20

def individual_bonus_calculator(name,income,goal,percent):
    if goal > 30:
        bonus = goal*(percent / 100 * income) + 10000
    elif 20 <= goal <= 30:
        bonus=goal*(percent / 100 * income) + 5000
    else:
        bonus = goal * (percent/100*income)
    print(f"{name} earned a bonus of {int(bonus)} taka for {goal} goals.")

individual_bonus_calculator("Neymar",1200000,35,5)

# %%
# Task 21

def individual_bonus_calculator(name,income,goal,percent):
            if goal>30:
                bonus = goal * (percent / 100 * income) + 10000
            elif 20 <= goal <= 30:
                bonus = goal* (percent / 100 * income) + 5000
            else:
                bonus = goal * (percent/100*income)
            print(f"{name} earned a bonus of {int(bonus)} taka for {goal} goals.")

def cal_bonus(*args):
    for i in range(0,len(args),4):
        name = args[i]
        income = args[i+1]
        goal = args[i+2]
        percent = args[i+3]
        individual_bonus_calculator(name,income,goal,percent)
    
cal_bonus("Neymar", 1200000, 30, 10, "Jamal", 700000, 19, 5)

# %% [markdown]
# **Bonus Task**

# %%
# Bonus Task 01
# Create diamond pattern with asterisks

n = int(input("please enter diamond's height: "))

for i in range(n):
    print(" " * (n - i), "*" * (i*2+1))
for i in range(n - 2, -1, -1):
    print(" " * (n - i), "*" * (i*2+1))

# This solution has base on height equals to top to the middle, or half of the height ...
# For example, this method will yield odd number actual height. Below is an example of n = 4(7).
# Yeah I know, she has this unignorable face, right? A diamond pattern this visage turned out to be, LMAO ?!
# Or maybe, that's just me forcing my thoughts, who knows, hehhee ¯\_(ツ)_/¯


# https://www.codingem.com/diamond-pattern-in-python-using-for-loop/

# %% [markdown]
# ![mahparism_n4(7).gif](data:image/gif;base64,...)

# %%
# Bonus Task 02
# Similar to 8th task of this lab assignment, you just have to create a pyramid,
# not once, but twice! Thus, make a DIAMOND. So yeah, there're few simple steps now:

def diamond_pattern(n):
  # Create a list of numbers from 1 to n
  numbers = [str(i) for i in range(1, n+1)]

  # Create the top half of the diamond
  for i in range(n):
    print(" " * (n-i-1) + " ".join(numbers[:i+1]) + " " * (n-i-1))

  # Create the bottom half of the diamond
  for i in range(n-2, -1, -1):
    print(" " * (n-i-1) + " ".join(numbers[:i+1]) + " " * (n-i-1))

# Test the function with n = 5
diamond_pattern(5)

# https://youtu.be/ybgdlPLwZH8
