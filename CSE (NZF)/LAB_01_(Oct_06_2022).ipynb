# %% [markdown]
# <a href="https://colab.research.google.com/github/SiliconJelly/BRACU/blob/main/CSE%20(NZF)/LAB_01_(Oct_06_2022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (1st lab) from these tasks, at CSE110 — 
# basically, we wtite our first Hello World today

print("Hello, CSE110 class !!")
print("~ Be greatful that BRACU starts with a robust language like Python! Hope you're excited!")
print("Now subscribe to SiliconJelly YT Channel, already!") # https://tiny.one/SiliconJelly

  # DOC link for the task sets:
  # https://docs.google.com/document/d/1kXpeLOz5iRhII79uOFB9Cfq1Tucev_h0ZV2_IB0o_lk

# %%
# Task 01

print("hello world!")

# %% [markdown]
# ![21617766_1471217376260469_9076028034688320768_n.jpg](data:image/jpeg;base64,...)

# %%
# Task 02

print(54+56)

# %%
# Task 03

season = "Fall"
year = 2022

print(season)
print(year)

# %%
# Task 04

name = input()
print("Your name is", name)

# %%
# Task 05

M = int(input())
N = int(input())

# print(M,'^',N,':', M**N)  

# concat, to exclude spacing
print(str(M)+'^'+str(N)+':'+str(M**N))

# %%
# Task 06
# Hint: 4 corners given; multiples of 4 then, right?

weight = int(input())
nearest_multiple = weight - (weight % 4)

print(nearest_multiple)

# %%
# Task 07

A = int(input())
B = int(input())
C = int(input())
D = float(input())

Formula110 = int(A**C + B * A - D/3)
print(Formula110)

# %%
# Task 08

total = int(input())
friends_recieve = total // 3
remaining = total % 3

print("Each friend will receive", friends_recieve,"chocolates")
print("The number of remaining chocolates is", remaining)

# %% [markdown]
# **Ungraded**

# %%
# Task 09
# string concatenation (bottom-up)

M = input() # by default, takes in string type as input
N = input()

print(N+M)

# %%
# Task 10
# indexing; printing first charachter

sentence = input("First character printer, give input please:")
print(sentence[0])

# %%
# Task 11
# branching and boolean; finding even vs odd

number = int(input())

if number % 2 == 0:
  print("True")

else:
  print("False")
